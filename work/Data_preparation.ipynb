# %%
# !pip install polars adbc-driver-postgresql s3fs numpy pyarrow

# %%
import os
import polars as pl
import numpy as np
import s3fs

# %%
db_uri = os.getenv("PG_URL")
#----------------------------------------------------------------------
MINIO_ENDPOINT = os.getenv("MINIO_URL", "http://minio:9000")
MINIO_ACCESS_KEY = os.getenv("MINIO_ACCESS_KEY")
MINIO_SECRET_KEY = os.getenv("MINIO_SECRET_KEY")
S3_BUCKET = "datalake"
#----------------------------------------------------------------------
storage_options = {
    "key": MINIO_ACCESS_KEY,
    "secret": MINIO_SECRET_KEY,
    "client_kwargs": {"endpoint_url": MINIO_ENDPOINT}
}

fs = s3fs.S3FileSystem(
    endpoint_url=os.getenv("MINIO_URL", "http://minio:9000"),
    key=os.getenv("MINIO_ACCESS_KEY", "minioadmin"),
    secret=os.getenv("MINIO_SECRET_KEY", "minioadmin")
)
S3_BUCKET = os.getenv("MINIO_DEFAULT_BUCKET", "datalake")
#----------------------------------------------------------------------
print("--- Настройки окружения ---")

# Логируем MinIO
print(f"MINIO_URL: {MINIO_ENDPOINT}")
print(f"MINIO_ACCESS_KEY: {MINIO_ACCESS_KEY}")

if MINIO_SECRET_KEY:
    print(f"MINIO_SECRET_KEY: {MINIO_SECRET_KEY[:3]}***{MINIO_SECRET_KEY[-3:]}")
else:
    print("MINIO_SECRET_KEY: None")

# Логируем S3
print(f"S3_BUCKET: {S3_BUCKET}")

# Логируем PostgreSQL
print(f"db_uri: {PG_URL}")

print("--------------------------")
# Out:
# --- Настройки окружения ---
# MINIO_URL: http://minio:9000
# MINIO_ACCESS_KEY: admin
# MINIO_SECRET_KEY: sup***ord
# S3_BUCKET: datalake
# db_uri: postgresql://admin:super_secret_pg_password@postgres:5432/company_data
# --------------------------
