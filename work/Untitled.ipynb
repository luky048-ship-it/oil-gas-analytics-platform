# %%
# !pip install sqlalchemy psycopg2-binary pandas pyarrow s3fs
# Out:
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.11/site-packages (2.0.22)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.11/site-packages (13.0.0)
# Collecting s3fs
#   Downloading s3fs-2026.4.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.24.4)
# Collecting aiobotocore<4.0.0,>=2.19.0 (from s3fs)
#   Downloading aiobotocore-3.7.0-py3-none-any.whl.metadata (28 kB)
# Collecting fsspec==2026.4.0 (from s3fs)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0 (from s3fs)
#   Downloading aiohttp-3.13.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<4.0.0,>=2.19.0->s3fs)
#   Downloading aioitertools-0.13.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting botocore<1.43.1,>=1.42.90 (from aiobotocore<4.0.0,>=2.19.0->s3fs)
#   Downloading botocore-1.43.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<4.0.0,>=2.19.0->s3fs)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting multidict<7.0.0,>=6.0.0 (from aiobotocore<4.0.0,>=2.19.0->s3fs)
#   Downloading multidict-6.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting wrapt<3.0.0,>=1.10.10 (from aiobotocore<4.0.0,>=2.19.0->s3fs)
#   Downloading wrapt-2.1.2-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs)
#   Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs)
#   Downloading propcache-0.5.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs)
#   Downloading yarl-1.23.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 665.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.43.1,>=1.42.90->aiobotocore<4.0.0,>=2.19.0->s3fs) (2.0.7)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (3.4)
# Downloading psycopg2_binary-2.9.12-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 5.4 MB/s eta 0:00:00a 0:00:01
# Downloading s3fs-2026.4.0-py3-none-any.whl (32 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 8.0 MB/s eta 0:00:00
# Downloading aiobotocore-3.7.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 6.8 MB/s eta 0:00:00
# Downloading aiohttp-3.13.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading botocore-1.43.0-py3-none-any.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 7.1 MB/s eta 0:00:0000:0100:01
# Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.1/231.1 kB 8.2 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading multidict-6.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.3/246.3 kB 7.7 MB/s eta 0:00:00
# Downloading propcache-0.5.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.5 MB/s eta 0:00:00
# Downloading wrapt-2.1.2-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.1/114.1 kB 7.3 MB/s eta 0:00:00
# Downloading yarl-1.23.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: wrapt, psycopg2-binary, propcache, multidict, jmespath, fsspec, frozenlist, aioitertools, aiohappyeyeballs, yarl, botocore, aiosignal, aiohttp, aiobotocore, s3fs
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.9.2
#     Uninstalling fsspec-2023.9.2:
#       Successfully uninstalled fsspec-2023.9.2
# Successfully installed aiobotocore-3.7.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aioitertools-0.13.0 aiosignal-1.4.0 botocore-1.43.0 frozenlist-1.8.0 fsspec-2026.4.0 jmespath-1.1.0 multidict-6.7.1 propcache-0.5.2 psycopg2-binary-2.9.12 s3fs-2026.4.0 wrapt-2.1.2 yarl-1.23.0

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# 1. Подключение к PostgreSQL
PG_URL = os.getenv("PG_URL", "postgresql://admin:super_secret_pg_password@postgres:5432/company_data")
engine = create_engine(PG_URL)

# Проверяем, что данные на месте
df_wells = pd.read_sql("SELECT * FROM wells", engine)
print("Скважины в БД:")
display(df_wells.head())

# 2. Настройки подключения к MinIO
MINIO_URL = os.getenv("MINIO_URL", "http://minio:9000")
MINIO_ACCESS_KEY = os.getenv("MINIO_ACCESS_KEY", "admin")
MINIO_SECRET_KEY = os.getenv("MINIO_SECRET_KEY", "super_secret_minio_password")
BUCKET_NAME = "datalake"

storage_options = {
    "key": MINIO_ACCESS_KEY,
    "secret": MINIO_SECRET_KEY,
    "client_kwargs": {"endpoint_url": MINIO_URL}
}
print("Подключения настроены успешно!")
# Out:
# Скважины в БД:
#    well_id      name    field_name         region  start_date     operator  \
# 0        1  Well-101   Severo-Ural   Khanty-Mansi  2018-03-15      UralOil
# 1        2  Well-102   Severo-Ural   Khanty-Mansi  2019-07-22      UralOil
# 2        3  Well-203  Vostok-Field  Yamalo-Nenets  2020-02-11  GazPromTech
# 3        4  Well-304   Zapad-Field          Tomsk  2017-05-01     RosDrill
# 4        5  Well-305   Zapad-Field          Tomsk  2019-11-03     RosDrill
#
#         status
# 0       active
# 1       active
# 2  maintenance
# 3    suspended
# 4       active
# Подключения настроены успешно!
